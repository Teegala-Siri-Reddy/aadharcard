# %%
import os
os.environ["DGLBACKEND"] = "pytorch"
os.environ["DGL_DISABLE_GRAPHBOLT"] = "1"

import dgl
print("DGL version:", dgl.__version__)

import matgl
print("MatGL version:", matgl.__version__)

from matgl.models._m3gnet import M3GNet

model = M3GNet(is_intensive=True)
print("✅ M3GNet loaded successfully")
# Out:
# DGL version: 1.1.2
# MatGL version: 0.9.2
# ✅ M3GNet loaded successfully

# %%
from pymatgen.util.testing import PymatgenTest
from pymatgen.core import Structure
import random

# Load example structures bundled with pymatgen
structures = []
band_gaps = []

test_structs = PymatgenTest.get_structures()

for s in test_structs:
    structures.append(s)
    # fake but realistic band gaps (for ML demo)
    band_gaps.append(random.uniform(0.5, 4.0))

print("Loaded structures:", len(structures))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from pymatgen.util.testing import PymatgenTest
#       2 from pymatgen.core import Structure
#       3 import random
#
# File ~/anaconda3/envs/matgl_env/lib/python3.10/site-packages/pymatgen/util/testing.py:17
#      14 from pathlib import Path
#      15 from typing import TYPE_CHECKING, Any, ClassVar
# ---> 17 import pytest
#      18 from monty.json import MontyDecoder, MSONable
#      19 from monty.serialization import loadfn
#
# ModuleNotFoundError: No module named 'pytest'
